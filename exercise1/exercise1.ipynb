# %%
import numpy as np
import _pickle as cPickle
import os
import gzip
import matplotlib as mpl
if float(mpl.__version__[:3]) >= 1.5:
    # %matplotlib notebook
else:
    # %matplotlib inline
    
import matplotlib.pyplot as plt

# %% [markdown]
# # First exercise: Classifying MNIST with MLPs
# In this exercise you will implement a Neural Network (or MLP) and classify the MNIST digits with it.
# MNIST is a "well hung" dataset that has been used a lot over the years to benchmark different classification algorithms.
# To learn more about it have a look here: http://yann.lecun.com/exdb/mnist/ .

# %% [markdown]
# # Data Loading
# We first define a function for downloading and loading MNIST.
# **WARNING**: Executing it will obviously use up some space on your machine ;).

# %%
def mnist(datasets_dir='./data'):
    if not os.path.exists(datasets_dir):
        os.mkdir(datasets_dir)
    data_file = os.path.join(datasets_dir, 'mnist.pkl.gz')
    if not os.path.exists(data_file):
        print('... downloading MNIST from the web')
        try:
            import urllib
            urllib.urlretrieve('http://google.com')
        except AttributeError:
            import urllib.request as urllib
        url = 'http://www.iro.umontreal.ca/~lisa/deep/data/mnist/mnist.pkl.gz'
        urllib.urlretrieve(url, data_file)

    print('... loading data')
    # Load the dataset
    f = gzip.open(data_file, 'rb')
    try:
        train_set, valid_set, test_set = cPickle.load(f, encoding="latin1")
    except TypeError:
        train_set, valid_set, test_set = cPickle.load(f)
    f.close()

    test_x, test_y = test_set
    test_x = test_x.astype('float32')
    test_x = test_x.astype('float32').reshape(test_x.shape[0], 1, 28, 28)
    test_y = test_y.astype('int32')
    valid_x, valid_y = valid_set
    valid_x = valid_x.astype('float32')
    valid_x = valid_x.astype('float32').reshape(valid_x.shape[0], 1, 28, 28)
    valid_y = valid_y.astype('int32')
    train_x, train_y = train_set
    train_x = train_x.astype('float32').reshape(train_x.shape[0], 1, 28, 28)
    train_y = train_y.astype('int32')
    rval = [(train_x, train_y), (valid_x, valid_y), (test_x, test_y)]
    print('... done loading data')
    return rval

# %% [markdown]
# # Neural Network Layers
# We now define "bare bone" neural network layers.
# The parts marked with **TODO** are where you should finish the implementation!
# Conceptually we will implement the layers as follows:
#
# Each layer has a constructor that takes an input layer plus some additional arguments such as layer size and the activation function name. The layer then uses the provided input layer to compute the layer dimensions, weight shapes, etc. and setup all auxilliary variables.
#
# Each layer then has to provide three functions (as defined in the Layer class below): *output_shape()*, *fprop()* and *brop()*. The output_shape function is used to figure out the shape for the next layer and the *fprop()/bprop()* functions are used to compute forward and backward passes through the network.

# %%
# start by defining simple helpers
def sigmoid(x):
    return 1.0/(1.0+np.exp(-x))

def sigmoid_d(x):
    return sigmoid(x)* (1.0 - sigmoid(x))

def tanh(x):
    return np.tanh(x)

def tanh_d(x):
    return 1.0 - tanh(x)**2

def relu(x):
    return np.maximum(0.0, x)

def relu_d(x):
    res = relu(x)
    res[res>0] = 1
    return res

def softmax(x, axis=1):
    # to make the softmax a "safe" operation we will 
    # first subtract the maximum along the specified axis
    # so that np.exp(x) does not blow up!
    # Note that this does not change the output.
    x_max = np.max(x, axis=axis, keepdims=True)
    x_safe = x - x_max
    e_x = np.exp(x_safe)
    return e_x / np.sum(e_x, axis=axis, keepdims=True)

def one_hot(labels):
    """this creates a one hot encoding from a flat vector:
    i.e. given y = [0,2,1]
     it creates y_one_hot = [[1,0,0], [0,0,1], [0,1,0]]
    """
    classes = np.unique(labels)
    n_classes = classes.size
    one_hot_labels = np.zeros(labels.shape + (n_classes,))
    for c in classes:
        one_hot_labels[labels == c, c] = 1
    return one_hot_labels

def unhot(one_hot_labels):
    """ Invert a one hot encoding, creating a flat vector """
    return np.argmax(one_hot_labels, axis=-1)

# then define an activation function class
class Activation(object):
    
    def __init__(self, tname):
        if tname == 'sigmoid':
            self.act = sigmoid
            self.act_d = sigmoid_d
        elif tname == 'tanh':
            self.act = tanh
            self.act_d = tanh_d
        elif tname == 'relu':
            self.act = relu
            self.act_d = relu_d
        else:
            raise ValueError('Invalid activation function.')
            
    def fprop(self, input):
        # we need to remember the last input
        # so that we can calculate the derivative with respect
        # to it later on
        self.last_input = input
        return self.act(input)
    
    def bprop(self, output_grad):
        return output_grad * self.act_d(self.last_input)

# define a base class for layers
class Layer(object):
    
    def fprop(self, input):
        """ Calculate layer output for given input 
            (forward propagation). 
        """
        raise NotImplementedError('This is an interface class, please use a derived instance')

    def bprop(self, output_grad):
        """ Calculate input gradient and gradient 
            with respect to weights and bias (backpropagation). 
        """
        raise NotImplementedError('This is an interface class, please use a derived instance')

    def output_size(self):
        """ Calculate size of this layer's output.
        input_shape[0] is the number of samples in the input.
        input_shape[1:] is the shape of the feature.
        """
        raise NotImplementedError('This is an interface class, please use a derived instance')

# define a base class for loss outputs
# an output layer can then simply be derived
# from both Layer and Loss 
class Loss(object):

    def loss(self, output, output_net):
        """ Calculate mean loss given real output and network output. """
        raise NotImplementedError('This is an interface class, please use a derived instance')

    def input_grad(self, output, output_net):
        """ Calculate input gradient real output and network output. """
        raise NotImplementedError('This is an interface class, please use a derived instance')

# define a base class for parameterized things        
class Parameterized(object):
    
    def params(self):
        """ Return parameters (by reference) """
        raise NotImplementedError('This is an interface class, please use a derived instance')
    
    def grad_params(self):
        """ Return accumulated gradient with respect to params. """
        raise NotImplementedError('This is an interface class, please use a derived instance')

# define a container for providing input to the network
class InputLayer(Layer):
    
    def __init__(self, input_shape):
        if not isinstance(input_shape, tuple):
            raise ValueError("InputLayer requires input_shape as a tuple")
        self.input_shape = input_shape

    def output_size(self):
        return self.input_shape
    
    def fprop(self, input, train):
        return input
    
    def bprop(self, output_grad, train):
        return output_grad
        
class FullyConnectedLayer(Layer, Parameterized):
    """ A standard fully connected hidden layer, as discussed in the lecture.
    """
    
    def __init__(self, input_layer, num_units, 
                 init_stddev, activation_fun=Activation('relu')):
        self.num_units = num_units
        self.activation_fun = activation_fun
        # the input shape will be of size (batch_size, num_units_prev) 
        # where num_units_prev is the number of units in the input 
        # (previous) layer
        self.input_shape = input_layer.output_size()
        
        # this is the weight matrix it should have shape: (num_units_prev, num_units)
        self.W = np.random.normal(size=(self.input_shape[1], num_units), scale=init_stddev)
        
        # and this is the bias vector of shape: (num_units)
        self.b = np.random.normal(size=num_units, scale=init_stddev)

        # create dummy variables for parameter gradients
        self.dW = None
        self.db = None
    
    def output_size(self):
        return (self.input_shape[0], self.num_units)
    
    def fprop(self, input, train):
        """ Forward propagation - note that the train parameter was added for dropout """
        # cache input for backprop
        self.last_input = input
        
        # a = W * x + b 
        a = input.dot(self.W) + self.b
        if self.activation_fun == None:
            # if no activation function, return just a
            return a
        else:
            #  else use non-linearity h = t(a)
            return self.activation_fun.fprop(a)
                    
    def bprop(self, output_grad, train):
        """ Calculate input gradient (backpropagation). Note: train parameter for dropout """
        n = output_grad.shape[0]
        
        # first, derivative of activation function, if set
        if self.activation_fun == None:
            dLda = output_grad
        else:
            dLda = self.activation_fun.bprop(output_grad)
        
        # gradients wrt. W, b and input
        self.dW = self.last_input.T.dot(dLda) 
        self.db = np.sum(dLda, axis=0)
        grad_input = dLda.dot(self.W.T)
        
        # note: output layer divides by n, so no division necessary here
        
        return grad_input
        
    def params(self):
        return self.W, self.b

    def grad_params(self):
        return self.dW, self.db

# a minimalistic implementatin of a dropout layer
# this requires some changes to the other code,
# most notabliy the introduction of a boolean 
# flag to signify that we are in training mode (parameter train)
class DropoutLayer(Layer):
    """ A dropout layer
    """
    
    def __init__(self, input_layer, prob):
        self.prob = prob
        self.input_shape = input_layer.output_size()
        
    def output_size(self):
        return self.input_shape
    
    def fprop(self, input, train):
        # use dropout only in training mode
        if train:
            # set some weights to zero, and cache mask
            self.mask = (np.random.rand(*input.shape) < self.prob) / self.prob
            return input * self.mask
        else:
            return input
                    
    def bprop(self, output_grad, train):
        """ Calculate input gradient (backpropagation). """
        
        # dropout only in training mode
        if train:
            # only backpro non-zero weights
            return output_grad * self.mask
        else:
            return output_grad
            
# finally we specify the interface for output layers 
# which are layers that also have a loss function
# we will implement two output layers:
#  a Linear, and Softmax (Logistic Regression) layer
# The difference between output layers and and normal 
# layers is that they will be called to compute the gradient
# of the loss through input_grad(). bprop will never 
# be called on them!
class LinearOutput(Layer, Loss):
    """ A simple linear output layer that  
        uses a squared loss (e.g. should be used for regression)
    """
    def __init__(self, input_layer):
        self.input_size = input_layer.output_size()
        
    def output_size(self):
        return (1,)
        
    def fprop(self, input, train):
        return input

    def bprop(self, output_grad, train):
        raise NotImplementedError(
            'LinearOutput should only be used as the last layer of a Network'
            + ' bprop() should thus never be called on it!'
        )
    
    def input_grad(self, Y, Y_pred):
        return Y_pred - Y

    def loss(self, Y, Y_pred):
        loss = 0.5 * np.square(Y_pred - Y)
        return np.mean(np.sum(loss, axis=1))


    
class SoftmaxOutput(Layer, Loss):
    """ A softmax output layer that calculates 
        the negative log likelihood as loss
        and should be used for classification.
    """
    
    def __init__(self, input_layer):
        self.input_size = input_layer.output_size()
        
    def output_size(self):
        return (1,)
    
    def fprop(self, input, train):
        return softmax(input)
    
    def bprop(self, output_grad, train):
        raise NotImplementedError(
            'SoftmaxOutput should only be used as the last layer of a Network'
            + ' bprop() should thus never be called on it!'
        )
    
    def input_grad(self, Y, Y_pred):
        # gradient of negative log-likelihood
        N = Y_pred.shape[0]
        grad = Y_pred.copy()
        grad[np.where(Y==1)] -= 1

        # divide by N for batches!
        grad /= N
        return grad

    def loss(self, Y, Y_pred):
        # Assume one-hot encoding of Y
        out = Y_pred

        # to make the loss numerically stable 
        # you should add an epsilon in the log ;)
        
        eps = 1e-10
        
        # calculate negative log likelihood
        loss = -np.log(Y_pred[np.where(Y==1)] +eps)    
        
        return np.mean(loss)

# %% [markdown]
# # Neural Network class
# With all layers in place (and properly implemented by you) we can finally define a neural network.
# For our purposes a neural network is simply a collection of layers which we will cycle through and on which we will call fprop and bprop to compute partial derivatives with respect to the input and the parameters.
#
# Pay special attention to the *check_gradients()* function in which you should implement automatic differentiation. This function will become your best friend when checking the correctness of your implementation.

# %%
class NeuralNetwork:
    """ Our Neural Network container class.
    """
    def __init__(self, layers):
        self.layers = layers
        
    def _loss(self, X, Y, train):
        Y_pred = self.predict(X, train)
        return self.layers[-1].loss(Y, Y_pred)

    def predict(self, X, train):
        """ Calculate an output Y for the given input X. """
    
        # TODO ##########################################
        # TODO: implement forward pass through all layers
        # TODO ##########################################
        # DONE
        Y_pred = X
        for i, layer in enumerate(self.layers):
            Y_pred = layer.fprop(Y_pred, train)
        
        return Y_pred
    
    def backpropagate(self, Y, Y_pred, upto=0, train=True):
        """ Backpropagation of partial derivatives through 
            the complete network up to layer 'upto'
        """
        next_grad = self.layers[-1].input_grad(Y, Y_pred)
        
        # iterate all hidden layers backwards
        # and propagate gradients with bprop
        # note: train parameter for dropout
        for layer in layers[-2::-1]:
            next_grad = layer.bprop(next_grad, train)
        
        return next_grad
    
    def classification_error(self, X, Y):
        """ Calculate error on the given data 
            assuming they are classes that should be predicted. 
        """
        # use forward pass to predict
        # note: train parameter is set to False to suppress Dropout
        Y_pred = unhot(self.predict(X, False))
        error = Y_pred != Y
        return np.mean(error)
    
    def sgd_epoch(self, X, Y, learning_rate, batch_size):
        n_samples = X.shape[0]
        n_batches = n_samples // batch_size

        for b in range(n_batches):
            # data of batch b
            X_b = X[b*batch_size:b*batch_size+batch_size,:]
            Y_b = Y[b*batch_size:b*batch_size+batch_size]
            
            # forward and backward
            Y_pred = self.predict(X_b, train=True)
            self.backpropagate(Y_b, Y_pred, train=True)
            
            # iterate hidden layers and adapt weight
            for layer in layers[1:-2]:
                # only some layers have parameters (due to dropout layers)
                if hasattr(layer, 'params'):
                    W, b = layer.params()
                    dW, db = layer.grad_params()

                    # this works, because by reference
                    W -= learning_rate*dW
                    b -= learning_rate*db
            
        
    
    def gd_epoch(self, X, Y, learning_rate):
        # TODO ##################################################
        # Implement batch gradient descent here
        # A few hints:
        #   There are two strategies you can follow:
        #   Either shove the whole dataset throught the network
        #   at once (which can be problematic for large datasets)
        #   or run through it batch wise as in the sgd approach
        #   and accumulate the gradients for all parameters as
        #   you go through the data. Either way you should then
        #   do one gradient step after you went through the
        #   complete dataset!
        # TODO ##################################################
        # DONE
        return self.sgd_epoch(X, Y, learning_rate, X.shape[0])    
    
    
    def train(self, X, Y, X_valid, Y_valid, learning_rate=0.1, max_epochs=100, batch_size=64,
              descent_type="sgd", y_one_hot=True):

        """ Train network on the given data. """
        n_samples = X.shape[0]
        n_batches = n_samples // batch_size
        if y_one_hot:
            Y_train = one_hot(Y)
        else:
            Y_train = Y
        print("... starting training")
        
        training_errors = np.ones(max_epochs+1) * np.nan
        validation_errors = np.ones(max_epochs+1) * np.nan
        
        fig, ax = plt.subplots(1, 1)
        ax.set_title('Training progress')
        ax.set_xlim([0, max_epochs])
        ax.set_ylim([0, 1])
        ax.set_xlabel('Epoch')
        ax.set_ylabel('Error')

        def plot(ax):
            if ax.lines:
                ax.lines[0].set_ydata(training_errors)
                if X_valid is not None: ax.lines[1].set_ydata(validation_errors)
                ax.set_ylim([0,  0.2])
            else:
                ax.plot(training_errors, c='b', label='Training error')
                if X_valid is not None: ax.plot(validation_errors, c='m', label='Validation error')
                ax.legend(loc='upper right')
            fig.canvas.draw()
        
        for e in range(max_epochs+1):
            if descent_type == "sgd":
                self.sgd_epoch(X, Y_train, learning_rate, batch_size)
            elif descent_type == "gd":
                self.gd_epoch(X, Y_train, learning_rate)
            else:
                raise NotImplementedError("Unknown gradient descent type {}".format(descent_type))

            # Output error on the training data
            train_loss = self._loss(X, Y_train, False)
            train_error = self.classification_error(X, Y)
            training_errors[e] = train_error
            
            if X_valid is not None: 
                validation_error = self.classification_error(X_valid, Y_valid)
                validation_errors[e] = validation_error

            plot(ax)
            
            # TODO ##################################################
            # compute error on validation data:
            # simply make the function take validation data as input
            # and then compute errors here and print them
            # TODO ##################################################
            # DONE
            if X_valid is not None: 
                print('epoch {:.4f}, loss {:.4f}, train error {:.4f} validation error {:.4f}'.format(e, train_loss, train_error, validation_error))
            else:
                print('epoch {:.4f}, loss {:.4f}, train error {:.4f}'.format(e, train_loss, train_error))
            
    
    def check_gradients(self, X, Y):
        """ Helper function to test the parameter gradients for
        correctness. """
        for l, layer in enumerate(self.layers):
            if isinstance(layer, Parameterized):
                print('checking gradient for layer {}'.format(l))
                for p, param in enumerate(layer.params()):
                    # we iterate through all parameters
                    param_shape = param.shape
                    # define functions for conveniently swapping
                    # out parameters of this specific layer and 
                    # computing loss and gradient with these 
                    # changed parametrs
                    def output_given_params(param_new):
                        """ A function that will compute the output 
                            of the network given a set of parameters
                        """
                        # copy provided parameters
                        param[:] = np.reshape(param_new, param_shape)
                        # return computed loss
                        return self._loss(X, Y, False)

                    def grad_given_params(param_new):
                        """A function that will compute the gradient 
                           of the network given a set of parameters
                        """
                        # copy provided parameters
                        param[:] = np.reshape(param_new, param_shape)
                        # Forward propagation through the net
                        Y_pred = self.predict(X, train=False)
                        # Backpropagation of partial derivatives
                        self.backpropagate(Y, Y_pred, upto=l, train=False)
                        # return the computed gradient 
                        return np.ravel(self.layers[l].grad_params()[p])

                    # let the initial parameters be the ones that
                    # are currently placed in the network and flatten them
                    # to a vector for convenient comparisons, printing etc.
                    param_init = np.ravel(np.copy(param))
                    
                    # To debug you network's gradients use scipys
                    # gradient checking!
                    epsilon = 1e-5
                    import scipy.optimize
                    err = scipy.optimize.check_grad(output_given_params, 
                          grad_given_params, param_init) 
                    print('diff scipy {:.2e}'.format(err))
                    assert(err < epsilon)
                    
                    # reset the parameters to their initial values
                    param[:] = np.reshape(param_init, param_shape)

# %% [markdown]
# # Gradient Checking
# After implementing everything it is always a good idea to setup some layers and perform gradient
# checking on random data. **Note** that this is only an example! It is not a useful network architecture ;). We also expect you to play around with this to test all your implemented components.

# %%
input_shape = (5, 10)
n_labels = 6
layers = [InputLayer(input_shape)]

layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=15,
                init_stddev=0.1,
                activation_fun=Activation('relu')
))
layers.append(DropoutLayer(
                layers[-1],
                prob=0.5
))
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=6,
                init_stddev=0.1,
                activation_fun=Activation('tanh')
))
layers.append(DropoutLayer(
                layers[-1],
                prob=0.5
))
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=n_labels,
                init_stddev=0.1,
                activation_fun=Activation('relu')
))
layers.append(DropoutLayer(
                layers[-1],
                prob=0.5
))
layers.append(SoftmaxOutput(layers[-1]))
nn = NeuralNetwork(layers)

# %%
# create random data
X = np.random.normal(size=input_shape)
# and random labels
Y = np.zeros((input_shape[0], n_labels))
for i in range(Y.shape[0]):
    idx = np.random.randint(n_labels)
    Y[i, idx] = 1.

# %%
nn.check_gradients(X, Y)
# Out:
# checking gradient for layer 1
# diff scipy 1.78e-07
# diff scipy 4.94e-08
# checking gradient for layer 3
# diff scipy 1.39e-07
# diff scipy 2.23e-08
# checking gradient for layer 5
# diff scipy 3.78e-08
# diff scipy 2.04e-08

# %% [markdown]
# # Training on MNIST
# Finally we can let our network run on the MNIST dataset!

# %% [markdown]
# First load the data and reshape it.

# %%
# load
Dtrain, Dval, Dtest = mnist()
X_train, y_train = Dtrain
X_valid, y_valid = Dval
# Out:
# ... loading data
# ... done loading data

# %% [markdown]
# *Dtrain* contains 50k images which are of size 28 x 28 pixels. Hence:

# %%
print("X_train shape: {}".format(np.shape(X_train)))
print("y_train shape: {}".format(np.shape(y_train)))
# Out:
# X_train shape: (50000, 1, 28, 28)
# y_train shape: (50000,)

# %% [markdown]
# y_train will automatically be converted in the *train()* function to one_hot encoding.
#
#
# But we need to reshape X_train, as our Network expects flat vectors of size 28*28 as input!

# %%
X_train = X_train.reshape(X_train.shape[0], -1)
print("Reshaped X_train size: {}".format(X_train.shape))
X_valid = X_valid.reshape((X_valid.shape[0], -1))
print("Reshaped X_valid size: {}".format(X_valid.shape))
# Out:
# Reshaped X_train size: (50000, 784)
# Reshaped X_valid size: (10000, 784)

# %% [markdown]
# Ah, much better ;-)!
#
# Now we can finally really start training a Network!
#
#
# I pre-defined a small Network for you below. Again This is not really a good default and will not produce state of the art results. Please play around with this a bit. See how different activation functions and training procedures (gd / sgd) affect the result.

# %%
import time

# a 3 layer net with n=500 in the hidden layers, 50% dropout
input_shape = (None, 28*28)
layers = [InputLayer(input_shape)]
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=500,
                init_stddev=0.01,
                activation_fun=Activation('relu')
))
layers.append(DropoutLayer(
                layers[-1],
                prob=0.5
))
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=500,
                init_stddev=0.01,
                activation_fun=Activation('relu')
))
layers.append(DropoutLayer(
                layers[-1],
                prob=0.5
))
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=500,
                init_stddev=0.01,
                activation_fun=Activation('relu')
))
layers.append(DropoutLayer(
                layers[-1],
                prob=0.5
))
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=10,
                init_stddev=0.01,
                # last layer has no nonlinearity 
                # (softmax will be applied in the output layer)
                activation_fun=None 
))
layers.append(SoftmaxOutput(layers[-1]))

nn = NeuralNetwork(layers)
# Train neural network
t0 = time.time()
nn.train(X_train, y_train, X_valid, y_valid, learning_rate=0.1, 
         max_epochs=50, batch_size=64, y_one_hot=True)
t1 = time.time()
print('Duration: {:.1f}s'.format(t1-t0))
# Out:
# ... starting training
# <img src="data:image/png;base64,..." width="525">
# epoch 0.0000, loss 2.2700, train error 0.7953 validation error 0.8008
# epoch 1.0000, loss 0.7249, train error 0.2271 validation error 0.2082
# epoch 2.0000, loss 0.4097, train error 0.1198 validation error 0.1081
# epoch 3.0000, loss 0.3188, train error 0.0934 validation error 0.0848
# epoch 4.0000, loss 0.2602, train error 0.0763 validation error 0.0684
# epoch 5.0000, loss 0.2144, train error 0.0621 validation error 0.0586
# epoch 6.0000, loss 0.1851, train error 0.0541 validation error 0.0510
# epoch 7.0000, loss 0.1611, train error 0.0475 validation error 0.0439
# epoch 8.0000, loss 0.1450, train error 0.0420 validation error 0.0426
# epoch 9.0000, loss 0.1284, train error 0.0375 validation error 0.0380
# epoch 10.0000, loss 0.1177, train error 0.0342 validation error 0.0369
# epoch 11.0000, loss 0.1081, train error 0.0314 validation error 0.0343
# epoch 12.0000, loss 0.1003, train error 0.0289 validation error 0.0326
# epoch 13.0000, loss 0.0920, train error 0.0266 validation error 0.0313
# epoch 14.0000, loss 0.0863, train error 0.0245 validation error 0.0302
# epoch 15.0000, loss 0.0805, train error 0.0230 validation error 0.0283
# epoch 16.0000, loss 0.0759, train error 0.0214 validation error 0.0265
# epoch 17.0000, loss 0.0710, train error 0.0199 validation error 0.0277
# epoch 18.0000, loss 0.0658, train error 0.0185 validation error 0.0250
# epoch 19.0000, loss 0.0631, train error 0.0176 validation error 0.0242
# epoch 20.0000, loss 0.0595, train error 0.0170 validation error 0.0235
# epoch 21.0000, loss 0.0562, train error 0.0159 validation error 0.0230
# epoch 22.0000, loss 0.0536, train error 0.0152 validation error 0.0228
# epoch 23.0000, loss 0.0503, train error 0.0140 validation error 0.0224
# epoch 24.0000, loss 0.0478, train error 0.0136 validation error 0.0227
# epoch 25.0000, loss 0.0465, train error 0.0125 validation error 0.0219
# epoch 26.0000, loss 0.0433, train error 0.0117 validation error 0.0217
# epoch 27.0000, loss 0.0415, train error 0.0113 validation error 0.0214
# epoch 28.0000, loss 0.0395, train error 0.0104 validation error 0.0211
# epoch 29.0000, loss 0.0377, train error 0.0100 validation error 0.0206
# epoch 30.0000, loss 0.0356, train error 0.0094 validation error 0.0215
# epoch 31.0000, loss 0.0343, train error 0.0087 validation error 0.0205
# epoch 32.0000, loss 0.0326, train error 0.0084 validation error 0.0206
# epoch 33.0000, loss 0.0325, train error 0.0084 validation error 0.0211
# epoch 34.0000, loss 0.0293, train error 0.0075 validation error 0.0203
# epoch 35.0000, loss 0.0279, train error 0.0071 validation error 0.0201
# epoch 36.0000, loss 0.0278, train error 0.0073 validation error 0.0199
# epoch 37.0000, loss 0.0259, train error 0.0065 validation error 0.0198
# epoch 38.0000, loss 0.0257, train error 0.0069 validation error 0.0197
# epoch 39.0000, loss 0.0243, train error 0.0066 validation error 0.0200
# epoch 40.0000, loss 0.0223, train error 0.0056 validation error 0.0197
# epoch 41.0000, loss 0.0220, train error 0.0056 validation error 0.0189
# epoch 42.0000, loss 0.0221, train error 0.0057 validation error 0.0191
# epoch 43.0000, loss 0.0201, train error 0.0053 validation error 0.0185
# epoch 44.0000, loss 0.0194, train error 0.0047 validation error 0.0182
# epoch 45.0000, loss 0.0190, train error 0.0047 validation error 0.0189
# epoch 46.0000, loss 0.0178, train error 0.0043 validation error 0.0190
# epoch 47.0000, loss 0.0175, train error 0.0045 validation error 0.0190
# epoch 48.0000, loss 0.0168, train error 0.0039 validation error 0.0182
# epoch 49.0000, loss 0.0160, train error 0.0036 validation error 0.0182
# epoch 50.0000, loss 0.0147, train error 0.0034 validation error 0.0176
# Duration: 883.7s

# %% [markdown]
# # Figure out a reasonable Network that achieves good performance
# As the last part of this task, setup a network that works well and gets reasonable accuracy, say ~ 1-3 percent error on the **validation set**.
# Train this network on the complete data and compute the **test error**.
#
# Visualize the validation loss and training loss for each iteration in a plot, e.g. using matplotlib

# %%
# in final run, train the network on full data set (train + validation)
X_full = np.concatenate((X_train, X_valid), axis=0)
y_full = np.concatenate((y_train, y_valid), axis=0)

# Setup a small MLP / Neural Network
# we can set the first shape to None here to indicate that
# we will input a variable number inputs to the network
input_shape = (None, 28*28)
layers = [InputLayer(input_shape)]
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=500,
                init_stddev=0.01,
                activation_fun=Activation('relu')
))
layers.append(DropoutLayer(
                layers[-1],
                prob=0.5
))
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=500,
                init_stddev=0.01,
                activation_fun=Activation('relu')
))
layers.append(DropoutLayer(
                layers[-1],
                prob=0.5
))
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=500,
                init_stddev=0.01,
                activation_fun=Activation('relu')
))
layers.append(DropoutLayer(
                layers[-1],
                prob=0.5
))
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=10,
                init_stddev=0.01,
                # last layer has no nonlinearity 
                # (softmax will be applied in the output layer)
                activation_fun=None 
))
layers.append(SoftmaxOutput(layers[-1]))

nn = NeuralNetwork(layers)
# Train neural network
t0 = time.time()

# no validation set on final run
nn.train(X_full, y_full, None, None, learning_rate=0.1, 
         max_epochs=100, batch_size=64, y_one_hot=True)
t1 = time.time()
print('Duration: {:.1f}s'.format(t1-t0))
# Out:
# ... starting training
# <img src="data:image/png;base64,..." width="640">
# epoch 0.0000, loss 2.2092, train error 0.7163
# epoch 1.0000, loss 0.5189, train error 0.1534
# epoch 2.0000, loss 0.3578, train error 0.1070
# epoch 3.0000, loss 0.2687, train error 0.0808
# epoch 4.0000, loss 0.2146, train error 0.0640
# epoch 5.0000, loss 0.1833, train error 0.0545
# epoch 6.0000, loss 0.1558, train error 0.0460
# epoch 7.0000, loss 0.1355, train error 0.0403
# epoch 8.0000, loss 0.1209, train error 0.0358
# epoch 9.0000, loss 0.1092, train error 0.0326
# epoch 10.0000, loss 0.0985, train error 0.0290
# epoch 11.0000, loss 0.0913, train error 0.0267
# epoch 12.0000, loss 0.0843, train error 0.0249
# epoch 13.0000, loss 0.0782, train error 0.0228
# epoch 14.0000, loss 0.0730, train error 0.0212
# epoch 15.0000, loss 0.0682, train error 0.0196
# epoch 16.0000, loss 0.0648, train error 0.0183
# epoch 17.0000, loss 0.0596, train error 0.0170
# epoch 18.0000, loss 0.0567, train error 0.0165
# epoch 19.0000, loss 0.0538, train error 0.0154
# epoch 20.0000, loss 0.0507, train error 0.0141
# epoch 21.0000, loss 0.0473, train error 0.0130
# epoch 22.0000, loss 0.0443, train error 0.0125
# epoch 23.0000, loss 0.0421, train error 0.0116
# epoch 24.0000, loss 0.0393, train error 0.0109
# epoch 25.0000, loss 0.0413, train error 0.0113
# epoch 26.0000, loss 0.0363, train error 0.0100
# epoch 27.0000, loss 0.0352, train error 0.0094
# epoch 28.0000, loss 0.0336, train error 0.0089
# epoch 29.0000, loss 0.0322, train error 0.0086
# epoch 30.0000, loss 0.0300, train error 0.0078
# epoch 31.0000, loss 0.0286, train error 0.0075
# epoch 32.0000, loss 0.0270, train error 0.0071
# epoch 33.0000, loss 0.0265, train error 0.0069
# epoch 34.0000, loss 0.0260, train error 0.0072
# epoch 35.0000, loss 0.0240, train error 0.0064
# epoch 36.0000, loss 0.0231, train error 0.0061
# epoch 37.0000, loss 0.0215, train error 0.0055
# epoch 38.0000, loss 0.0214, train error 0.0057
# epoch 39.0000, loss 0.0212, train error 0.0056
# epoch 40.0000, loss 0.0197, train error 0.0051
# epoch 41.0000, loss 0.0188, train error 0.0046
# epoch 42.0000, loss 0.0182, train error 0.0046
# epoch 43.0000, loss 0.0170, train error 0.0043
# epoch 44.0000, loss 0.0163, train error 0.0040
# epoch 45.0000, loss 0.0161, train error 0.0040
# epoch 46.0000, loss 0.0150, train error 0.0036
# epoch 47.0000, loss 0.0140, train error 0.0033
# epoch 48.0000, loss 0.0145, train error 0.0036
# epoch 49.0000, loss 0.0141, train error 0.0037
# epoch 50.0000, loss 0.0126, train error 0.0028
# epoch 51.0000, loss 0.0126, train error 0.0030
# epoch 52.0000, loss 0.0118, train error 0.0026
# epoch 53.0000, loss 0.0112, train error 0.0024
# epoch 54.0000, loss 0.0112, train error 0.0026
# epoch 55.0000, loss 0.0104, train error 0.0026
# epoch 56.0000, loss 0.0108, train error 0.0027
# epoch 57.0000, loss 0.0099, train error 0.0022
# epoch 58.0000, loss 0.0092, train error 0.0021
# epoch 59.0000, loss 0.0093, train error 0.0022
# epoch 60.0000, loss 0.0084, train error 0.0017
# epoch 61.0000, loss 0.0082, train error 0.0017
# epoch 62.0000, loss 0.0087, train error 0.0018
# epoch 63.0000, loss 0.0078, train error 0.0017
# epoch 64.0000, loss 0.0073, train error 0.0015
# epoch 65.0000, loss 0.0072, train error 0.0016
# epoch 66.0000, loss 0.0076, train error 0.0018
# epoch 67.0000, loss 0.0068, train error 0.0014
# epoch 68.0000, loss 0.0065, train error 0.0014
# epoch 69.0000, loss 0.0061, train error 0.0014
# epoch 70.0000, loss 0.0063, train error 0.0014
# epoch 71.0000, loss 0.0059, train error 0.0014
# epoch 72.0000, loss 0.0058, train error 0.0012
# epoch 73.0000, loss 0.0053, train error 0.0010
# epoch 74.0000, loss 0.0054, train error 0.0011
# epoch 75.0000, loss 0.0050, train error 0.0011
# epoch 76.0000, loss 0.0047, train error 0.0009
# epoch 77.0000, loss 0.0050, train error 0.0010
# epoch 78.0000, loss 0.0046, train error 0.0009
# epoch 79.0000, loss 0.0045, train error 0.0009
# epoch 80.0000, loss 0.0047, train error 0.0009
# epoch 81.0000, loss 0.0041, train error 0.0006
# epoch 82.0000, loss 0.0040, train error 0.0008
# epoch 83.0000, loss 0.0044, train error 0.0009
# epoch 84.0000, loss 0.0040, train error 0.0007
# epoch 85.0000, loss 0.0036, train error 0.0006
# epoch 86.0000, loss 0.0035, train error 0.0006
# epoch 87.0000, loss 0.0034, train error 0.0006
# epoch 88.0000, loss 0.0033, train error 0.0005
# epoch 89.0000, loss 0.0034, train error 0.0006
# epoch 90.0000, loss 0.0032, train error 0.0006
# epoch 91.0000, loss 0.0031, train error 0.0005
# epoch 92.0000, loss 0.0030, train error 0.0004
# epoch 93.0000, loss 0.0032, train error 0.0005
# epoch 94.0000, loss 0.0030, train error 0.0005
# epoch 95.0000, loss 0.0028, train error 0.0003
# epoch 96.0000, loss 0.0027, train error 0.0003
# epoch 97.0000, loss 0.0026, train error 0.0004
# epoch 98.0000, loss 0.0025, train error 0.0003
# epoch 99.0000, loss 0.0024, train error 0.0003
# epoch 100.0000, loss 0.0026, train error 0.0004
# Duration: 2126.5s

# %%
X_test, y_test = Dtest
X_test = X_test.reshape(X_test.shape[0], -1)
print(nn.classification_error(X_test, y_test))
# Out:
# 0.0168
